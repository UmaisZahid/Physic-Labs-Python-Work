# %%
#Import NumPy for use in our arrays
import numpy as np
#Import matplotlib module for graph plotting.
import matplotlib.pyplot as plt
#Tells notebook to put plots within a notebook
# %matplotlib inline

# %%
frequency1= 100,500,1000,2000,4000,6000,6050,6100,6200,7000,10000,20000,40000,60000,80000,100000,400000,700000,1000000
print(array_a)

gain1=126,126,126,126,126,124,124,124,124,120,110,84,68,54,45,13,13,8,5
print(gain1)

frequency2 = 100,150,170,180,185,200,300,400,500,1000,1500,10000,50000
gain2= 1280,1280,1280,1280,1240,1240,1240,1240,1240,1220,1180,450,92

frequency3= 100000,200000,400000,500000,600000,700000,800000,900000,1000000
gain3= 120,180,160,210,160,170,180,180,170

frequency4=100,1000,5000,10000,15000,20000,25000,30000,40000,100000,200000,300000,400000,500000,750000,1000000
gain4=120,120,140,170,210,240,270,340,330,370,370,360,360,340,300,250
# Out:
# (100, 500, 1000, 2000, 4000, 6000, 6050, 6100, 6200, 7000, 10000, 20000, 40000, 60000, 80000, 100000, 400000, 700000, 1000000)
# (126, 126, 126, 126, 126, 124, 124, 124, 124, 120, 110, 84, 68, 54, 45, 13, 13, 8, 5)

# %%
#plot data points
plt.plot(frequency1,gain1,'bo', label="$\mathit{Line \  of \ least \ squares \ fit \ (Unweighted)}$", linewidth=1.25)
plt.plot(frequency2,gain2,'ro')
plt.plot(frequency3,gain3,'go')
plt.plot(frequency4,gain4,'co')
plt.grid(True)

plt.yscale('log')
plt.xscale('log')

plt.title ('Experimental Gain Agaisnt Frequency on Log Graph ')
plt.xlabel('log(Frequency),Hz')
plt.ylabel('log(Gain)')
